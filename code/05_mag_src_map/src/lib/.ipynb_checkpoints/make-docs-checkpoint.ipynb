# %%
import pdoc

target = input("Which module would you like to produce documentation for (include '.py'): ")
print("\n")
# Out:
# Which module would you like to produce documentation for (include '.py'):  GRS

# %%
help(pdoc)
# Out:
# Help on package pdoc:
#
# NAME
#     pdoc
#
# DESCRIPTION
#     Python package `pdoc` provides types, functions, and a command-line
#     interface for accessing public documentation of Python modules, and
#     for presenting it in a user-friendly, industry-standard open format.
#     It is best suited for small- to medium-sized projects with tidy,
#     hierarchical APIs.
#
#     .. include:: ./documentation.md
#
# PACKAGE CONTENTS
#     __main__
#     _version
#     cli
#     html_helpers
#     test (package)
#
# CLASSES
#     builtins.dict(builtins.object)
#         Context
#     builtins.object
#         Doc
#             Class
#             External
#             Function
#             Module
#             Variable
#
#     class Class(Doc)
#      |  Class(name, module, obj, *, docstring=None)
#      |
#      |  Representation of a class' documentation.
#      |
#      |  Method resolution order:
#      |      Class
#      |      Doc
#      |      builtins.object
#      |
# ...
